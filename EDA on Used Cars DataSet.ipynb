# %% [markdown]
# # Exploratory Data Analysis (EDA) on Used Cars DataSet

# %% [markdown]
# ## What is EDA?
# Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.

# %% [markdown]
# # Understand the Dataset
#
# In this dataset, we are trying to analyze the used car’s price and how EDA focuses on identifying the factors influencing the car price. We have stored the data in the DataFrame data.
#
# The dataset have 7253 rows and 14 columns. Column description given below.
#
# * **S.No.** = Serial number for the rows
# * **Name** = Name of the car
# * **Location** = Originated location of the Car
# * **Year** = Originated year of the car
# * **Kilometers_Driven** = number of kilometers driven by the respective car
# * **Fuel_Type** = type of fuel used in respective car
# * **Transmission** = Manual/Automatic
# * **Owner_Type** = type of the owner i.e., first, second, third,..
# * **Mileage** = mileage of car
# * **Engine** = engine number
# * **Power** = power of car in bhp
# * **Seats** = number of seats in the car
# * **New_Price** = latest price of car
# * **Price** = earliest price of car

# %% [markdown]
# # Importing Libraries
#
# The first step is understanding and playing around with our data using libraries.
# import all libraries which are required for our analysis.
# Pandas and Numpy have been used for data manipulations and numerical calculations
# Matplotlib and Seaborn have been used for data visualizations

# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##  Reading Dataset
# The Pandas library offers a wide range of possibilities for loading data into the pandas DataFrame from files like JSON, .csv, .xlsx, .sql, .pickle, .html, .txt, images etc.
#
# Most of the data are available in a tabular format of CSV files. Using the `read_csv()` function, data can be converted to a pandas DataFrame.
#
# In this dataset, we are trying to analyze the used car's price and how EDA focuses on identifying the factors influencing the car price. Here, we have stored the data in the DataFrame dat

# %%
data = pd.read_csv("used_cars_data.csv")

# %% [markdown]
# ## Analyzing the Data
# The main goal of data understanding is to gain general insights about the data, which covers the number of rows and columns, values in the data, datatypes, and Missing values in the dataset.
#
# There are 7253 observations and 14 variables in our dataset

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %% [markdown]
# `head()` will display the top 5 observations of the dataset.
# If we want 10 or 100 or any particular number of top observations then we mention the particular number in the braces like `head(9)`, `head(100)`.

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %% [markdown]
# `tail()` will display the last 5 observations of the dataset.
# If we want 10 or 100 or any particular number of last observations then we mention the particular number in the braces like `tail(28)`, `tail(50)`

# %%
data.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# ...

# %% [markdown]
# `info()` helps to understand the data type and information about data, including the number of records in each column, data having null or not null, Data type, the memory usage of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %% [markdown]
# ## Renaming the data
#
# `rename()` is a function that alters the axis labels. Here, the word "axis" refers to both rows and columns depending on which value we set for the parameter axis in this function.
# Here, we renaming the column names from "Mileage" = "Mileage(kmpl)","Engine" = "Engine(CC)","Power" = "Power(bhp)","New_Price" = "New_Price(in Lakhs)"

# %%
new_data = data.rename(columns={"Mileage": "Mileage(kmpl)","Engine": "Engine(CC)","Power": "Power(bhp)","New_Price": "New_Price(in Lakhs)"})
new_data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %% [markdown]
# ## Extracting data and Changing datatype
#
# `str.extract()` is a function which is used to extract the numerical value from a string
# For changing the object data to float, we use `.astype()` or `pd.to_numeric()`
# Here, we extract the numerical values from a object datatype and convert them into float datatype

# %%
new_data['Mileage(kmpl)']=new_data['Mileage(kmpl)'].str.extract(r'(\d+.\d+)').astype('float')
new_data['Engine(CC)']=new_data['Engine(CC)'].str.extract(r'(\d+.\d+)').astype('float')
new_data['Power(bhp)']=new_data['Power(bhp)'].str.extract(r'(\d+.\d+)').astype('float')
new_data['New_Price(in Lakhs)']=new_data['New_Price(in Lakhs)'].str.extract(r'(\d+.\d+)').astype('float')

# %%
new_data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   S.No.                7253 non-null   int64
#  1   Name                 7253 non-null   object
#  2   Location             7253 non-null   object
#  3   Year                 7253 non-null   int64
#  4   Kilometers_Driven    7253 non-null   int64
#  5   Fuel_Type            7253 non-null   object
#  6   Transmission         7253 non-null   object
#  7   Owner_Type           7253 non-null   object
#  8   Mileage(kmpl)        7251 non-null   float64
#  9   Engine(CC)           7206 non-null   float64
#  10  Power(bhp)           5926 non-null   float64
#  11  Seats                7200 non-null   float64
#  12  New_Price(in Lakhs)  989 non-null    float64
#  13  Price                6019 non-null   float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 793.4+ KB

# %% [markdown]
# ## Check for Duplication
# `nunique()` based on several unique values in each column and the data description, we can identify the continuous and categorical columns in the data.

# %%
new_data.nunique()
# Out:
# S.No.                  7253
# Name                   2041
# Location                 11
# Year                     23
# Kilometers_Driven      3660
# Fuel_Type                 5
# Transmission              2
# Owner_Type                4
# Mileage(kmpl)           438
# Engine(CC)              149
# Power(bhp)              347
# Seats                     9
# New_Price(in Lakhs)     616
# Price                  1373
# dtype: int64

# %% [markdown]
# ## Missing Values Calculation
#
# `isnull()` is widely been in all pre-processing steps to identify null values in the data
#
# In this dataset, `new_data.isnull().sum()` is used to get the number of missing records in each column

# %%
new_data.isnull().sum()
# Out:
# S.No.                     0
# Name                      0
# Location                  0
# Year                      0
# Kilometers_Driven         0
# Fuel_Type                 0
# Transmission              0
# Owner_Type                0
# Mileage(kmpl)             2
# Engine(CC)               47
# Power(bhp)             1327
# Seats                    53
# New_Price(in Lakhs)    6264
# Price                  1234
# dtype: int64

# %% [markdown]
# ## Impute Missing values
#
# Missing data arise in almost all statistical analyses. There are many ways to impute missing values; we can impute the missing values by their Mean, median, most frequent, or zero values and use advanced imputation algorithms like KNN, Regularization, etc.
#
# We cannot impute the data with a simple Mean/Median. We must need business knowledge or common insights about the data. If we have domain knowledge, it will add value to the imputation. Some data can be imputed on assumptions.
#
# In our dataset, we have found there are missing values for many columns like Mileage(kmpl), Engine(CC), Power(bhp), Seats, New_Price(in Lakhs) and Price. We could fix this by filling null values with zero for this we use `fillna()` and then the median value of respective column since Mean and Median values are nearly the same for this variable chosen Median to impute the values.

# %%
new_data[[ 'Mileage(kmpl)','Engine(CC)','Power(bhp)','Seats','New_Price(in Lakhs)','Price']] = new_data[[ 'Mileage(kmpl)','Engine(CC)','Power(bhp)','Seats','New_Price(in Lakhs)','Price']].fillna(new_data[[ 'Mileage(kmpl)','Engine(CC)','Power(bhp)','Seats','New_Price(in Lakhs)','Price']].median())
new_data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
new_data.isnull().sum()
# Out:
# S.No.                  0
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage(kmpl)          0
# Engine(CC)             0
# Power(bhp)             0
# Seats                  0
# New_Price(in Lakhs)    0
# Price                  0
# dtype: int64

# %% [markdown]
# The below code is used to calculate the percentage of missing values in each column

# %%
(new_data.isnull().sum()/(len(new_data)))*100
# Out:
# S.No.                  0.0
# Name                   0.0
# Location               0.0
# Year                   0.0
# Kilometers_Driven      0.0
# Fuel_Type              0.0
# Transmission           0.0
# Owner_Type             0.0
# Mileage(kmpl)          0.0
# Engine(CC)             0.0
# Power(bhp)             0.0
# Seats                  0.0
# New_Price(in Lakhs)    0.0
# Price                  0.0
# dtype: float64

# %% [markdown]
# ## Data Reduction
# Some columns or variables can be dropped if they do not add value to our analysis.
#
# In our dataset, the column S.No have only ID values, assuming they don’t have any predictive power to predict the dependent variable.
# we can drop this by using the function `drop()`

# %%
new_data = new_data.drop(['S.No.'], axis = 1)
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 7253 non-null   object
#  1   Location             7253 non-null   object
#  2   Year                 7253 non-null   int64
#  3   Kilometers_Driven    7253 non-null   int64
#  4   Fuel_Type            7253 non-null   object
#  5   Transmission         7253 non-null   object
#  6   Owner_Type           7253 non-null   object
#  7   Mileage(kmpl)        7253 non-null   float64
#  8   Engine(CC)           7253 non-null   float64
#  9   Power(bhp)           7253 non-null   float64
#  10  Seats                7253 non-null   float64
#  11  New_Price(in Lakhs)  7253 non-null   float64
#  12  Price                7253 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 736.8+ KB

# %% [markdown]
# ## Feature Engineering
# Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data when creating a predictive model using machine learning or statistical modeling. The main goal of Feature engineering is to create meaningful data from raw data.

# %% [markdown]
# ## Creating Features
# We will play around with the variables Year and Name in our dataset. If we see the dataset, the column “Year” shows the manufacturing year of the car.
# It would be difficult to find the car’s age
# if it is in year format as the Age of the car is a contributing factor to Car Price.
#
# Introducing a new column, “Car_Age” to know the age of the car

# %%
from datetime import date
date.today().year
new_data['Car_Age']=date.today().year-new_data['Year']
new_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC)  Power(bhp)  \
# 0       CNG       Manual      First          26.60       998.0       58.16
# 1    Diesel       Manual      First          19.67      1582.0      126.20
# 2    Petrol       Manual      First          18.20      1199.0       88.70
# 3    Diesel       Manual      First          20.77      1248.0       88.76
# 4    Diesel    Automatic     Second          15.20      1968.0      140.80
#
#    Seats  New_Price(in Lakhs)  Price  Car_Age
# ...

# %% [markdown]
# Let’s split the car name and introduce new variables “Brand” and “Model” to extract important information

# %%
new_data['Brand'] = new_data.Name.str.split().str.get(0)

# %%
new_data['Model'] = new_data.Name.str.split().str.get(1) + new_data.Name.str.split().str.get(2)

# %%
new_data[['Name','Brand','Model']]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                  Model
# 0               WagonR
# 1             Creta1.6
# 2                JazzV
# ...

# %% [markdown]
# ## Data Cleaning/Wrangling
# Some names of the variables are not relevant and not easy to understand. Some data may have data entry errors, and some variables may need data type conversion. We need to fix this issue in the data.
#
# In the Following, The brand name ‘Isuzu’ ‘ISUZU’ and ‘Mini’ and ‘Land’ looks incorrect. This needs to be corrected

# %%
print(new_data.Brand.unique())
print(new_data.Brand.nunique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']
# 33

# %%
searchfor = ['Isuzu' ,'ISUZU','Mini','Land']
new_data[new_data.Brand.str.contains('|'.join(searchfor))].head(5)
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC)  Power(bhp)  \
# 13     Diesel    Automatic      First          12.70      2179.0      187.70
# 14     Diesel    Automatic     Second           0.00      2179.0      115.00
# 176    Diesel    Automatic     Second          16.60      1998.0      112.00
# 191    Diesel    Automatic      First          12.70      2179.0      187.70
# 228    Petrol    Automatic      First          16.82      1998.0      189.08
#
# ...

# %%
new_data["Brand"].replace({"ISUZU": "Isuzu", "Mini": "Mini Cooper","Land":"Land Rover"}, inplace=True)

# %% [markdown]
# ## EDA Exploratory Data Analysis
# Exploratory Data Analysis refers to the crucial process of performing initial investigations on data to discover patterns to check assumptions with the help of summary statistics and graphical representations.
#
# * EDA can be leveraged to check for outliers, patterns, and trends in the given data.
#
# * EDA helps to find meaningful patterns in data.
#
# * EDA provides in-depth insights into the data sets to solve our business problems.
#
# * EDA gives a clue to impute missing values in the dataset

# %% [markdown]
# ## Statistics Summary
# The information gives a quick and simple description of the data.
#
# Can include Count, Mean, Standard Deviation, median, mode, minimum value, maximum value, range, standard deviation, etc.

# %% [markdown]
# `describe()` provide a statistics summary of data belonging to numerical datatype such as int, float

# %%
new_data.describe().T
# Out:
#                       count          mean           std      min       25%  \
# Year                 7253.0   2013.365366      3.254421  1996.00   2011.00
# Kilometers_Driven    7253.0  58699.063146  84427.720583   171.00  34000.00
# Mileage(kmpl)        7253.0     18.141586      4.561567     0.00     15.17
# Engine(CC)           7253.0   1615.985661    593.200036   624.00   1198.00
# Power(bhp)           7253.0    117.226856     50.324565    34.20     86.80
# Seats                7253.0      5.277678      0.809039     0.00      5.00
# New_Price(in Lakhs)  7253.0     12.449189      7.934938     1.02     11.27
# Price                7253.0      8.826235     10.293313     0.44      3.85
# Car_Age              7253.0      9.634634      3.254421     4.00      7.00
#
#                           50%       75%         max
# Year                  2014.00   2016.00     2019.00
# Kilometers_Driven    53416.00  73000.00  6500000.00
# Mileage(kmpl)           18.16     21.10       33.54
# ...

# %% [markdown]
# `describe(include=’all’)` provides a statistics summary of all data, include object, category etc

# %%
new_data.describe(include='object').T
# Out:
#              count unique                     top  freq
# Name          7253   2041  Mahindra XUV500 W8 2WD    55
# Location      7253     11                  Mumbai   949
# Fuel_Type     7253      5                  Diesel  3852
# Transmission  7253      2                  Manual  5204
# Owner_Type    7253      4                   First  5952
# Brand         7253     32                  Maruti  1444
# Model         7252    726              SwiftDzire   189

# %% [markdown]
# separate Numerical and categorical variables for easy analysis

# %%
cat_cols=new_data.select_dtypes(include=['object']).columns
num_cols = new_data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')
# Numerical Variables:
# ['Year', 'Kilometers_Driven', 'Mileage(kmpl)', 'Engine(CC)', 'Power(bhp)', 'Seats', 'New_Price(in Lakhs)', 'Price', 'Car_Age']

# %% [markdown]
# ## EDA Univariate Analysis
# Analyzing/visualizing the dataset by taking one variable at a time:
#
# Data visualization is essential; we must decide what charts to plot to better understand the data. In this, we visualize our data using Matplotlib and Seaborn libraries.
#
# Matplotlib is a Python 2D plotting library used to draw basic charts we use Matplotlib.
#
# Seaborn is also a python library built on top of Matplotlib that uses short lines of code to create and style statistical plots from Pandas and Numpy.
#
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.

# %% [markdown]
# For this dataset, we have done a Univariate analysis using Histogram and  Box Plot for continuous Variables.
#
# In the below fig, a histogram and box plot is used to show the pattern of the variables, as some variables have skewness and outliers.

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(new_data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    new_data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=new_data[col])
    plt.show()
# Out:
# Year
# Skew : -0.84
# Kilometers_Driven
# Skew : 61.58
# Mileage(kmpl)
# Skew : -0.44
# Engine(CC)
# Skew : 1.42
# Power(bhp)
# Skew : 2.12
# Seats
# Skew : 1.91
# New_Price(in Lakhs)
# Skew : 6.51
# Price
# Skew : 3.74
# Car_Age
# Skew : 0.84

# %% [markdown]
# categorical variables are being visualized using a count plot.
# Categorical variables provide the pattern of factors influencing car price

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Fuel_Type', data = new_data, color = 'blue', 
              order = new_data['Fuel_Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Transmission', data = new_data, color = 'blue', 
              order = new_data['Transmission'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Owner_Type', data = new_data, color = 'blue', 
              order = new_data['Owner_Type'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Location', data = new_data, color = 'blue', 
              order = new_data['Location'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Brand', data = new_data, color = 'blue', 
              order = new_data['Brand'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Model', data = new_data, color = 'blue', 
              order = new_data['Model'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %% [markdown]
# Log transformation can help in normalization, so this variable can maintain standard scale with other variables

# %%
# Function for log transformation of the column
def log_transform(new_data,col):
    for colname in col:
        if (new_data[colname] == 1.0).all():
            new_data[colname + '_log'] = np.log(new_data[colname]+1)
        else:
            new_data[colname + '_log'] = np.log(new_data[colname])
    new_data.info()

# %%
log_transform(new_data,['Kilometers_Driven','Price'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7253 non-null   object
#  1   Location               7253 non-null   object
#  2   Year                   7253 non-null   int64
#  3   Kilometers_Driven      7253 non-null   int64
#  4   Fuel_Type              7253 non-null   object
#  5   Transmission           7253 non-null   object
#  6   Owner_Type             7253 non-null   object
#  7   Mileage(kmpl)          7253 non-null   float64
#  8   Engine(CC)             7253 non-null   float64
#  9   Power(bhp)             7253 non-null   float64
#  10  Seats                  7253 non-null   float64
#  11  New_Price(in Lakhs)    7253 non-null   float64
#  12  Price                  7253 non-null   float64
#  13  Car_Age                7253 non-null   int64
# ...

# %%
#Log transformation of the feature 'Kilometers_Driven'
sns.distplot(new_data["Kilometers_Driven_log"], axlabel="Kilometers_Driven_log");

# %%
#Log transformation of the feature 'price'
sns.distplot(new_data["Price_log"], axlabel="price_log");

# %% [markdown]
# ## EDA Bivariate Analysis
# Bivariate Analysis helps to understand how variables are related to each other and the relationship between dependent and independent variables present in the dataset.
#
# For Numerical variables, Pair plots and Scatter plots are widely been used to do Bivariate Analysis.
#
# A Stacked bar chart can be used for categorical variables if the output variable is a classifier. Bar plots can be used if the output variable is continuous
#
# for this dataset, a pair plot has been used to show the relationship between two Categorical Variables.

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data = new_data.drop(['Kilometers_Driven','Price'],axis=1))
plt.show()

# %% [markdown]
# A bar plot can be used to show the relationship between Categorical variables and continuous variables

# %%
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))
new_data.groupby('Location')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Location Vs Price", fontsize=18)
new_data.groupby('Transmission')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("Transmission Vs Price", fontsize=18)
new_data.groupby('Fuel_Type')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("Fuel_Type Vs Price", fontsize=18)
new_data.groupby('Owner_Type')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Owner_Type Vs Price", fontsize=18)
new_data.groupby('Brand')['Price_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][0], fontsize=12)
axarr[2][0].set_title("Brand Vs Price", fontsize=18)
new_data.groupby('Model')['Price_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][1], fontsize=12)
axarr[2][1].set_title("Model Vs Price", fontsize=18)
new_data.groupby('Seats')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][0], fontsize=12)
axarr[3][0].set_title("Seats Vs Price", fontsize=18)
new_data.groupby('Car_Age')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][1], fontsize=12)
axarr[3][1].set_title("Car_Age Vs Price", fontsize=18)
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()

# %% [markdown]
# ## EDA Multivariate Analysis
#
# As the name suggests, Multivariate analysis looks at more than two variables. Multivariate analysis is one of the most useful methods to determine relationships and analyze patterns for any dataset.
#
# A heat map is widely been used for Multivariate Analysis
#
# Heat Map gives the correlation between the variables, whether it has a positive or negative correlation.
#
# In our dataset heat map shows the correlation between the variables.

# %%
df_main = pd.read_csv('used_cars_data.csv')
df_used_cars = df_main.copy()

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(new_data.drop(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
       'Model','Kilometers_Driven_log','Price_log'],axis=1).corr(), annot = True, vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# <center><h1> HAPPY LEARNING
